# %% [markdown]
# # Chapter 3: Data Manipulation with Pandas
# ## By: Parisa Hormozzadeh
#
# Pandas is a powerful and easy-to-use Python library for data analysis and manipulation.
#
# It builds on numpy and provides data structures and functions to work with tabular and time series data.
#
# ---

# %% [markdown]
# ## 1. Installing and Importing Pandas
# - Pandas usually comes pre-installed with Anaconda.
# - If not, install with:
#
# ```bash
# pip install pandas
# ```
#
# - Import pandas as:
# ---

# %%
import pandas as pd

# %% [markdown]
# ## 2. Pandas Series
# A Series is a one-dimensional labeled array capable of holding any data type.
#
# ### 2.1. Creating a Series from a list:

# %%
voltages = [220, 230, 210, 225]
voltage_series = pd.Series(voltages)
voltage_series
# Out:
# 0    220
# 1    230
# 2    210
# 3    225
# dtype: int64

# %% [markdown]
# ### 2.2. Creating a Series with custom index labels:

# %%
labels = ['T1', 'T2', 'T3', 'T4']
voltage_series_custom = pd.Series(voltages, index=labels)
print(voltage_series_custom)
# Out:
# T1    220
# T2    230
# T3    210
# T4    225
# dtype: int64

# %% [markdown]
# ## 3. Pandas DataFrame
# DataFrame is a 2D labeled data structure with columns of potentially different types.
#
# ### 3.1. Creating a DataFrame from a dictionary:

# %%
data = {
    'Voltage': [220, 230, 210, 225],
    'Current': [10, 15, 9, 12],
    'Status': ['ON', 'ON', 'OFF', 'ON']
}
df = pd.DataFrame(data)
df
# Out:
#    Voltage  Current Status
# 0      220       10     ON
# 1      230       15     ON
# 2      210        9    OFF
# 3      225       12     ON

# %% [markdown]
# ### 3.2. Creating DataFrame from CSV file
# We have a CSV file named `power_consumption.csv`, we can read it as:
#
#
#
# ---

# %%
df = pd.read_csv('power_consumption.csv')
df.head()
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
# 3  1/1/2017 0:30        6.121      75.0      0.083                0.091
# 4  1/1/2017 0:40        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3 PowerDemandCategory
# 0             20240.96386                 Low
# 1             20131.08434                 Low
# 2             19668.43373                 Low
# 3             18899.27711                 Low
# 4             18442.40964                 Low

# %% [markdown]
# ## 4. Viewing Data
# - `head()` shows first 5 rows (default)
# - `tail()` shows last 5 rows (default)
# - `info()` shows summary including data types and missing values
# - `describe()` shows statistical summary for numerical columns
#
# ---

# %%
print('\nInfo:')
df.info()
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datetime                52416 non-null  object
#  1   Temperature             52416 non-null  float64
#  2   Humidity                52416 non-null  float64
#  3   WindSpeed               52416 non-null  float64
#  4   GeneralDiffuseFlows     52416 non-null  float64
#  5   DiffuseFlows            52416 non-null  float64
#  6   PowerConsumption_Zone1  52416 non-null  float64
#  7   PowerConsumption_Zone2  52416 non-null  float64
#  8   PowerConsumption_Zone3  52416 non-null  float64
#  9   PowerDemandCategory     52416 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 4.0+ MB

# %%
print('\nDescribe:')
df.describe()
# Out:
# Describe:
#         Temperature      Humidity     WindSpeed  GeneralDiffuseFlows  \
# count  52416.000000  52416.000000  52416.000000         52416.000000
# mean      18.810024     68.259518      1.959489           182.696614
# std        5.815476     15.551177      2.348862           264.400960
# min        3.247000     11.340000      0.050000             0.004000
# 25%       14.410000     58.310000      0.078000             0.062000
# 50%       18.780000     69.860000      0.086000             5.035500
# 75%       22.890000     81.400000      4.915000           319.600000
# max       40.010000     94.800000      6.483000          1163.000000
#
#        DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# count  52416.000000            52416.000000            52416.000000
# mean      75.028022            32344.970564            21042.509082
# std      124.210949             7130.562564             5201.465892
# min        0.011000            13895.696200             8560.081466
# 25%        0.122000            26310.668692            16980.766032
# 50%        4.456000            32265.920340            20823.168405
# 75%      101.000000            37309.018185            24713.717520
# max      936.000000            52204.395120            37408.860760
#
#        PowerConsumption_Zone3
# count            52416.000000
# mean             17835.406218
# std               6622.165099
# min               5935.174070
# 25%              13129.326630
# 50%              16415.117470
# 75%              21624.100420
# max              47598.326360

# %% [markdown]
# ## 5. Selecting Data
# ### Select column by name

# %%
Temperature = df['Temperature']
Temperature
# Out:
# 0        6.559
# 1        6.414
# 2        6.313
# 3        6.121
# 4        5.921
#          ...
# 52411    7.010
# 52412    6.947
# 52413    6.900
# 52414    6.758
# 52415    6.580
# Name: Temperature, Length: 52416, dtype: float64

# %% [markdown]
# #### ✅ .loc[] and .iloc[]

# %% [markdown]
# | Feature    | `.loc`                        | `.iloc`                 |
# | ---------- | ----------------------------- | ----------------------- |
# | Uses       | **Labels** (row/column names) | **Integer positions**   |
# | Example    | `df.loc[3, "Humidity"]`       | `df.iloc[3, 2]`         |
# | Common Use | When you know column names    | When you know positions |

# %%
# 1. Get Temperature at row with index 1
df.loc[1, "Temperature"]
# Out:
# 6.414

# %%
# 2. Get Humidity for rows 0 and 2
df.loc[[0, 2], "Humidity"]
# Out:
# 0    73.8
# 2    74.5
# Name: Humidity, dtype: float64

# %%
# 3. Get full row for index 0
df.loc[0]
# Out:
# Datetime                  1/1/2017 0:00
# Temperature                       6.559
# Humidity                           73.8
# WindSpeed                         0.083
# GeneralDiffuseFlows               0.051
# DiffuseFlows                      0.119
# PowerConsumption_Zone1       34055.6962
# PowerConsumption_Zone2      16128.87538
# PowerConsumption_Zone3      20240.96386
# PowerDemandCategory                 Low
# Name: 0, dtype: object

# %%
# 1. Get Temperature at row 1, column 1
df.iloc[1, 1]
# Out:
# 6.414

# %%
# 2. Get first two rows
df.iloc[0:2]
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
#
#    PowerConsumption_Zone3 PowerDemandCategory
# 0             20240.96386                 Low
# 1             20131.08434                 Low

# %%
# 3. Get only the "PowerConsumption_Zone1" column for all rows
df.iloc[:, 4]
# Out:
# 0        0.051
# 1        0.070
# 2        0.062
# 3        0.091
# 4        0.048
#          ...
# 52411    0.040
# 52412    0.051
# 52413    0.084
# 52414    0.066
# 52415    0.062
# Name: GeneralDiffuseFlows, Length: 52416, dtype: float64

# %% [markdown]
# ## 6. Filtering Data
# Using boolean conditions to filter rows.
#
#
# ---

# %%
high_temperature = df[df['Temperature'] > 8]
high_temperature
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 67       1/1/2017 11:10         8.22     61.90      4.916
# 68       1/1/2017 11:20         9.49     59.30      2.451
# 69       1/1/2017 11:30        10.65     56.03      0.084
# 70       1/1/2017 11:40        11.06     53.52      0.082
# 71       1/1/2017 11:50        12.40     53.26      0.080
# ...                 ...          ...       ...        ...
# 52396  12/30/2017 20:40         9.37     64.52      0.085
# 52397  12/30/2017 20:50         9.29     64.25      0.085
# 52398  12/30/2017 21:00         8.80     65.49      0.082
# 52403  12/30/2017 21:50         8.14     69.73      0.081
# 52404  12/30/2017 22:00         8.09     68.49      0.079
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 67                 388.200        33.890             29043.03797
# 68                 401.300        34.400             29261.77215
# 69                 419.500        35.290             29474.43038
# 70                 430.900        37.580             29523.03797
# 71                 437.500        43.460             29711.39241
# ...                    ...           ...                     ...
# 52396                0.073         0.089             36879.08745
# 52397                0.070         0.085             36623.57414
# 52398                0.088         0.115             36343.72624
# 52403                0.062         0.085             34469.96198
# 52404                0.070         0.085             34920.15209
#
#        PowerConsumption_Zone2  PowerConsumption_Zone3  PowerDemandCategory  \
# 67                17478.41945             15816.86747                    0
# 68                17792.09726             15932.53012                    0
# 69                17748.32827             16053.97590                    0
# 70                17963.52584             16256.38554                    0
# 71                18142.24924             16354.69880                    0
# ...                       ...                     ...                  ...
# 52396             31828.16815             16929.65186                    1
# 52397             31806.07548             16941.17647                    1
# 52398             31345.81160             16877.79112                    1
# 52403             29688.86161             16180.55222                    1
# 52404             29445.84228             16053.78151                    1
#
#        new_column
# 67       40.40952
# 68       23.25999
# 69        0.89460
# 70        0.90692
# 71        0.99200
# ...           ...
# 52396     0.79645
# 52397     0.78965
# 52398     0.72160
# 52403     0.65934
# 52404     0.63911
#
# [51360 rows x 11 columns]

# %% [markdown]
# ## 7. Adding, Modifying, and Deleting Columns
# ---

# %%
# Add new column 
df['new_column'] = df['WindSpeed'] * df['Temperature']
df.head()
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
# 3  1/1/2017 0:30        6.121      75.0      0.083                0.091
# 4  1/1/2017 0:40        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3  PowerDemandCategory  new_column
# 0             20240.96386                    0    0.544397
# 1             20131.08434                    0    0.532362
# 2             19668.43373                    0    0.505040
# 3             18899.27711                    0    0.508043
# 4             18442.40964                    0    0.479601

# %%
# Modify 'Status' column
df['PowerDemandCategory'] = df['PowerDemandCategory'].replace({'Low': 0, 'High': 1})
df
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# 3                    0.091         0.096             28228.86076
# 4                    0.048         0.085             27335.69620
# ...                    ...           ...                     ...
# 52411                0.040         0.096             31160.45627
# 52412                0.051         0.093             30430.41825
# 52413                0.084         0.074             29590.87452
# 52414                0.066         0.089             28958.17490
# 52415                0.062         0.111             28349.80989
#
#        PowerConsumption_Zone2  PowerConsumption_Zone3  PowerDemandCategory  \
# 0                 16128.87538             20240.96386                    0
# 1                 19375.07599             20131.08434                    0
# 2                 19006.68693             19668.43373                    0
# 3                 18361.09422             18899.27711                    0
# 4                 17872.34043             18442.40964                    0
# ...                       ...                     ...                  ...
# 52411             26857.31820             14780.31212                    1
# 52412             26124.57809             14428.81152                    0
# 52413             25277.69254             13806.48259                    0
# 52414             24692.23688             13512.60504                    0
# 52415             24055.23167             13345.49820                    0
#
#        new_column
# 0        0.544397
# 1        0.532362
# 2        0.505040
# 3        0.508043
# 4        0.479601
# ...           ...
# 52411    0.560800
# 52412    0.569654
# 52413    0.593400
# 52414    0.540640
# 52415    0.532980
#
# [52416 rows x 11 columns]

# %% [markdown]
# ## 8. Sorting Data
#
# ---

# %%
df_sorted = df.sort_values(by='Temperature', ascending=False)
df_sorted
# Out:
#               Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 29034  7/21/2017 15:00       40.010     14.54      0.070              798.000
# 29033  7/21/2017 14:50       39.780     14.27      0.070              814.000
# 29035  7/21/2017 15:10       39.760     14.94      0.072              784.000
# 29031  7/21/2017 14:30       39.740     14.47      0.069              834.000
# 29030  7/21/2017 14:20       39.730     14.37      0.066              842.000
# ...                ...          ...       ...        ...                  ...
# 3494    1/25/2017 6:20        3.582     79.20      0.087                0.070
# 3495    1/25/2017 6:30        3.555     79.50      0.087                0.073
# 3486    1/25/2017 5:00        3.541     80.80      0.085                0.055
# 3488    1/25/2017 5:20        3.441     82.80      0.086                0.051
# 3487    1/25/2017 5:10        3.247     82.40      0.086                0.088
#
#        DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 29034        85.400             37889.70100             26753.16456
# 29033        86.200             38151.22924             26821.51899
# 29035        83.600             37915.21595             26722.78481
# 29031        88.900             38323.45515             27037.97468
# 29030        90.300             38642.39203             27102.53165
# ...             ...                     ...                     ...
# 3494          0.163             25470.37975             15446.80851
# 3495          0.152             25525.06329             15519.75684
# 3486          0.115             22584.30380             13798.17629
# 3488          0.119             22906.32911             13903.95137
# 3487          0.085             22547.84810             13714.28571
#
#        PowerConsumption_Zone3  PowerDemandCategory  new_column
# 29034             29408.53556                    1    2.800700
# 29033             29342.25941                    1    2.784600
# 29035             29203.68201                    1    2.862720
# 29031             29553.13808                    1    2.742060
# 29030             29715.81590                    1    2.622180
# ...                       ...                  ...         ...
# 3494              14989.87952                    0    0.311634
# 3495              14827.95181                    0    0.309285
# 3486              14232.28916                    0    0.300985
# 3488              14376.86747                    0    0.295926
# 3487              14226.50602                    0    0.279242
#
# [52416 rows x 11 columns]

# %% [markdown]
# ## 9. Aggregation and Grouping
#
# ---

# %%
grouped = df.groupby('PowerDemandCategory').agg({'PowerConsumption_Zone1': ['mean', 'max' , 'sum']})
grouped
# Out:
#                     PowerConsumption_Zone1
#                                       mean          max           sum
# PowerDemandCategory
# High                          38550.101491  52204.39512  9.225425e+08
# Low                           27131.876366  38652.14209  7.728515e+08

# %% [markdown]
# ## Summary
# - Pandas is essential for tabular data manipulation.
# - Series and DataFrame are core data structures.
# - Use loc/iloc for selecting data.
# - Boolean indexing helps filter data.
# - Learn to add, modify, delete columns and handle missing data.
# - Aggregation and grouping help summarize data.
#
# Next: We'll cover **Data Preprocessing Essentials**.
